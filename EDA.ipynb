# %%
import numpy as np
import pandas as pd
import seaborn as sns


# pd.set_option('display.max_columns', None)  # or 1000
# pd.set_option('display.max_rows', None)  # or 1000
# pd.set_option('display.max_colwidth', -1)  # or 199

# %%
df = pd.read_csv('clean final2.csv')
df
# Out:
#         price  year manufacturer  condition  cylinders fuel  odometer  \
# 0       33590  2014          gmc       good          8  gas   57923.0
# 1       22590  2010    chevrolet       good          8  gas   71229.0
# 2       39590  2020    chevrolet       good          8  gas   19160.0
# 3       30990  2017       toyota       good          8  gas   41124.0
# 4       15000  2013         ford  excellent          6  gas  128000.0
# ...       ...   ...          ...        ...        ...  ...       ...
# 117318  29590  2016       toyota       good          6  gas   53475.0
# 117319  32990  2016     infiniti       good          8  gas   55612.0
# 117320  33590  2018        lexus       good          6  gas   30814.0
# 117321  23590  2019       nissan       good          6  gas   32226.0
# 117322  28990  2018        lexus       good          6  gas   30112.0
#
#        title_status transmission    type     model1  age
# 0             clean        other  pickup     sierra    8
# ...

# %%
sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.2)

# %% [markdown]
# >>- most reliable manufacturer
# >>- honda as the diffrance betwwen good and excelant is the most

# %%
sns.countplot( y="manufacturer", data=df,hue='condition')
# Out:
# <AxesSubplot:xlabel='count', ylabel='manufacturer'>

# %% [markdown]
# >>- most selling engin in the dataset
# >>- 6 cylinders is the most populer engin in the dataset

# %%
sns.countplot(x='cylinders',data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %% [markdown]
# >>- manufacturer with the highest mean price
# >>- ram is the manufactuer with the highst mean price

# %%
sns.barplot(x="price", y="manufacturer", data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='manufacturer'>

# %% [markdown]
# >>-most expensive engin
#
# >>-8 cylinders engin is the most cylinders engins

# %%
sns.stripplot(y="price", x="cylinders", data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='price'>

# %% [markdown]
# -->most selling brand
# -->fort is the best selling brand

# %%
sns.countplot( y="manufacturer", data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='manufacturer'>

# %% [markdown]
# -->most selling model
# -->chevorlet silvardo is the most selling car

# %%
df['model1'].value_counts()
# Out:
# silverado    5780
# 1500         3510
# sierra       3359
# wrangler     2957
# f150         2545
#              ...
# e450           19
# mirage         14
# v70            14
# s40            12
# leaf            8
# Name: model1, Length: 329, dtype: int64

# %%
dff=pd.pivot_table(index='manufacturer',columns='model1',data=df,values='price', aggfunc='count')
dff
# Out:
# model1           1500    200   2500      3  3-series    300  300c  325i  \
# manufacturer
# acura             NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# audi              NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# bmw               NaN    NaN    NaN  309.0     117.0    NaN   NaN  59.0
# buick             NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# cadillac          NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# chevrolet        44.0    NaN   51.0    NaN       NaN    NaN   NaN   NaN
# chrysler          NaN  394.0    NaN    NaN       NaN  558.0  65.0   NaN
# dodge             3.0    NaN    5.0    NaN       NaN    NaN   NaN   NaN
# ford              NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# gmc              27.0    NaN   25.0    NaN       NaN    NaN   NaN   NaN
# honda             NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# hyundai           NaN    NaN    NaN    NaN       NaN    NaN   NaN   NaN
# ...

# %% [markdown]
# >>- best selling body type fore each brand

# %%
sns.countplot( y="manufacturer", data=df,hue='type')
# Out:
# <AxesSubplot:xlabel='count', ylabel='manufacturer'>

# %%
dfff=pd.pivot_table(index='manufacturer',columns='type',data=df,values='price', aggfunc='sum')
dfff
# Out:
# type                  SUV  convertible       coupe  hatchback   mini-van  \
# manufacturer
# acura          17587219.0          NaN     32500.0    34702.0     3999.0
# audi            9108066.0    1785369.0   8396282.0   501658.0        NaN
# bmw            12858996.0    3476622.0   4453958.0  1263204.0        NaN
# buick          14549361.0          NaN     26745.0    35495.0        NaN
# cadillac       14596434.0          NaN    882695.0   123993.0        NaN
# chevrolet      43151275.0   10777779.0  41072005.0  2980602.0   379690.0
# chrysler         177667.0     975349.0    303490.0   260591.0  4430374.0
# dodge           9637669.0          NaN  28907563.0   319626.0  5885659.0
# ford           47597208.0    7091528.0  32592399.0  4469726.0  1398660.0
# gmc            30676135.0          NaN         NaN    89594.0    10995.0
# honda          19892507.0       3500.0   4841352.0  4177423.0  5170825.0
# hyundai         6168924.0          NaN   3101084.0  1300872.0        NaN
# ...

# %%
sns.heatmap(dfff,annot=False )
# Out:
# <AxesSubplot:xlabel='type', ylabel='manufacturer'>

# %%
dfff=pd.pivot_table(index='manufacturer',columns='year',data=df,values='price', aggfunc='count').transpose()
dfff
# Out:
# manufacturer  acura   audi    bmw  buick  cadillac  chevrolet  chrysler  \
# year
# 1994            NaN    NaN    1.0    2.0       8.0       73.0       NaN
# 1995            NaN    NaN    1.0    3.0       3.0       67.0       NaN
# 1996            2.0    1.0    7.0    3.0       3.0       72.0      10.0
# 1997            NaN    2.0   21.0    5.0       6.0       82.0       3.0
# 1998            1.0    1.0   26.0    8.0       4.0       75.0       2.0
# 1999            4.0    2.0   20.0    5.0      13.0      152.0       5.0
# 2000            5.0    6.0   39.0   28.0      15.0      137.0       8.0
# 2001            6.0   18.0   37.0   20.0      11.0      214.0      15.0
# 2002           12.0   18.0   40.0   35.0      20.0      310.0      40.0
# 2003           20.0   18.0   50.0   62.0      32.0      353.0      45.0
# 2004           44.0   23.0   46.0   43.0      51.0      374.0      63.0
# 2005           65.0   33.0   67.0   59.0      64.0      498.0     159.0
# ...

# %%
sns.heatmap(dfff,annot=False,cmap='viridis' )
# Out:
# <AxesSubplot:xlabel='manufacturer', ylabel='year'>

# %% [markdown]
# --> dose more miles affect price

# %%
sns.jointplot( y="price",x='odometer' ,data=df)

# %% [markdown]
# >>- most selling transmetion
# >>- automatic transmetion

# %%
sns.countplot(x='transmission',data=df)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='count'>

# %% [markdown]
# >>- most expensive transmition
# >>-other transmitions

# %%
sns.barplot(x='transmission',y='price',estimator = np.mean,data=df)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='price'>

# %% [markdown]
# -->most seling body type

# %%
sns.countplot(y='type',data=df )
# Out:
# <AxesSubplot:xlabel='count', ylabel='type'>

# %% [markdown]
# >>-most reliable body type

# %%
dfff=pd.pivot_table(index='type',columns='condition',data=df,values='price', aggfunc='count')
dfff
# Out:
# condition    excellent   good  like new
# type
# SUV              14734  10382      3161
# convertible       1063    807       274
# coupe             1973   4281       551
# hatchback         2066   1507       462
# mini-van          1416    903       325
# other              690   5675       139
# pickup            4095  12179       677
# sedan            15204  12553      3704
# truck             6090   5053      1652
# van               1231   1557       372
# wagon             1274   1032       241

# %%
sns.heatmap(dfff,annot=True,cmap='viridis' )
# Out:
# <AxesSubplot:xlabel='condition', ylabel='type'>

# %%
sns.countplot(y='type',data=df , hue='condition')
# Out:
# <AxesSubplot:xlabel='count', ylabel='type'>

# %% [markdown]
# >>-most expensive body type

# %%
dfff=pd.pivot_table(index='type',columns='condition',data=df,values='price', aggfunc='mean')
dfff
# Out:
# condition       excellent          good      like new
# type
# SUV          13960.188544  16145.880177  17247.984815
# convertible  14679.096896  20758.178439  17569.667883
# coupe        13298.512924  27975.113992  17985.500907
# hatchback     9494.955470   8485.155275  11769.608225
# mini-van     10712.749294   6501.301218  13146.652308
# other        15407.002899  30828.306608  16675.705036
# pickup       21145.457387  28561.026603  25807.706056
# sedan         9811.060905  13235.101171  11345.699784
# truck        23994.580624  19035.399169  30040.919492
# van          16777.252640  17207.000642  22988.540323
# wagon        12638.122449   9928.859496  11059.609959

# %%
sns.heatmap(dfff,annot=True,cmap='viridis' )
# Out:
# <AxesSubplot:xlabel='condition', ylabel='type'>
