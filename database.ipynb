# %%
# !pip install mysqlclient

# %%
# !pip install sqlalchemy
# !pip install  pymysql
# !pip install mysql-connector-python

# %%
import time
import mysql.connector
from datetime import date
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta
import numpy as np
import pandas as pd

# %%
# df=pd.DataFrame.from_records(ads)
# df

df = pd.read_csv('clean final2.csv')
df
# Out:
#         price  year manufacturer  condition  cylinders fuel  odometer  \
# 0       33590  2014          gmc       good          8  gas   57923.0
# 1       22590  2010    chevrolet       good          8  gas   71229.0
# 2       39590  2020    chevrolet       good          8  gas   19160.0
# 3       30990  2017       toyota       good          8  gas   41124.0
# 4       15000  2013         ford  excellent          6  gas  128000.0
# ...       ...   ...          ...        ...        ...  ...       ...
# 117318  29590  2016       toyota       good          6  gas   53475.0
# 117319  32990  2016     infiniti       good          8  gas   55612.0
# 117320  33590  2018        lexus       good          6  gas   30814.0
# 117321  23590  2019       nissan       good          6  gas   32226.0
# 117322  28990  2018        lexus       good          6  gas   30112.0
#
#        title_status transmission    type     model1  age
# 0             clean        other  pickup     sierra    8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117323 entries, 0 to 117322
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         117323 non-null  int64
#  1   year          117323 non-null  int64
#  2   manufacturer  117323 non-null  object
#  3   condition     117323 non-null  object
#  4   cylinders     117323 non-null  int64
#  5   fuel          117323 non-null  object
#  6   odometer      117323 non-null  float64
#  7   title_status  117323 non-null  object
#  8   transmission  117323 non-null  object
#  9   type          117323 non-null  object
#  10  model1        117323 non-null  object
#  11  age           117323 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 10.7+ MB

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="56734",
  database="cregslists"

)
mycursor = mydb.cursor()

# %%
mycursor.execute("CREATE DATABASE cregslists")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Can't create database 'cregslist'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 mycursor.execute("CREATE DATABASE cregslist")
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql://root:56734@localhost/cregslistss" )
df.to_sql('cars', con = engine, if_exists = 'append',index = True)

# %%
mycursor.execute("SELECT price,manufacturer,model1 FROM cars WHERE price >=10000")

myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# (12500, 'ford', 'mustang')
# (29975, 'jeep', 'wrangler')
# (19999, 'toyota', 'tacoma')
# (12999, 'subaru', 'forester')
# (14972, 'subaru', 'legacy')
# (13000, 'gmc', 'sierra')
# (15200, 'chevrolet', 'silverado')
# (16299, 'nissan', 'altima')
# (10000, 'ford', 'f350')
# (23000, 'jeep', 'compass')
# (17999, 'subaru', 'forester')
# (17382, 'subaru', 'crosstrek')
# (15372, 'subaru', 'impreza')
# (26470, 'chevrolet', 'silverado')
# (21842, 'chevrolet', 'silverado')
# (16975, 'ram', 'pickup')
# (16972, 'subaru', 'legacy')
# (23852, 'chevrolet', 'silverado')
# (16750, 'subaru', 'outback')
# (27492, 'toyota', 'tacoma')
# ...

# %%
mycursor.execute("SELECT price,manufacturer,model1 FROM cars WHERE year >=2000 lIMIT 100")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (33590, 'gmc', 'sierra')
# (22590, 'chevrolet', 'silverado')
# (39590, 'chevrolet', 'silverado')
# (30990, 'toyota', 'tundra')
# (15000, 'ford', 'f-150')
# (27990, 'gmc', 'sierra')
# (34590, 'chevrolet', 'silverado')
# (35000, 'toyota', 'tacoma')
# (29990, 'chevrolet', 'colorado')
# (38590, 'chevrolet', 'corvette')
# (32990, 'jeep', 'wrangler')
# (24590, 'chevrolet', 'silverado')
# (37990, 'chevrolet', 'camaro')
# (27990, 'nissan', 'frontier')
# (34590, 'ford', 'f150')
# (38990, 'ford', 'f150')
# (22590, 'ram', '1500')
# (19900, 'ford', 'f250')
# (26990, 'ford', 'f150')
# (25590, 'gmc', 'sierra')
# (14000, 'honda', 'odyssey')
# (28590, 'ram', '1500')
# (24590, 'gmc', 'sierra')
# (25990, 'ram', '1500')
# (34990, 'ford', 'mustang')
# (22500, 'ford', 'f450')
# (31990, 'toyota', 'tundra')
# (29990, 'chevrolet', 'silverado')
# (23990, 'chevrolet', 'silverado')
# (26990, 'chevrolet', 'silverado')
# (33990, 'jeep', 'wrangler')
# (15000, 'dodge', 'charger')
# (29590, 'ford', 'expedition')
# ...

# %%
mycursor.execute("SELECT odometer ,model1,price FROM cars WHERE price BETWEEN 15000 AND 20000 ORDER BY price ASC")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (76350.0, 'mkx', 15000)
# (156000.0, 'silverado', 15000)
# (117489.0, 'f150', 15000)
# (84176.0, 'f150', 15000)
# (130000.0, 'impala', 15000)
# (99500.0, 'wrangler', 15000)
# (160000.0, 'grand', 15000)
# (120000.0, 'z3', 15000)
# (44000.0, 'fusion', 15000)
# (97000.0, 'tahoe', 15000)
# (80000.0, 'charger', 15000)
# (97000.0, 'tahoe', 15000)
# (23000.0, 'sierra', 15000)
# (44000.0, 'fusion', 15000)
# (89333.0, 'escape', 15000)
# (55500.0, 'a6', 15000)
# (90000.0, 'camaro', 15000)
# (154000.0, '4runner', 15000)
# (156296.0, '1500', 15000)
# (91000.0, 'santa', 15000)
# (104000.0, '1500', 15000)
# (246000.0, 'f-250', 15000)
# (111000.0, 'wrx', 15000)
# (75000.0, 'camaro', 15000)
# (92919.0, 'rav4', 15000)
# (71100.0, 'town', 15000)
# (110000.0, 'rav4', 15000)
# (111000.0, 'f-150', 15000)
# (92919.0, 'rav4', 15000)
# (132214.0, 'silverado', 15000)
# (70000.0, 'equinox', 15000)
# (181000.0, 'yukon', 15000)
# (84000.0, 'e350', 15000)
# (84000.0, 'e350', 15000)
# ...

# %%
mycursor.execute("SELECT odometer ,model1,price FROM cars WHERE odometer BETWEEN 150000 AND 200000 ORDER BY odometer ASC")
myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (150000.0, 'sienna', 1700)
# (150000.0, 'grand', 9500)
# (150000.0, 'sierra', 26900)
# (150000.0, 'equinox', 7495)
# (150000.0, 'f-150', 5500)
# (150000.0, 'f150', 4900)
# (150000.0, 'silverado', 8995)
# (150000.0, 'f-150', 2000)
# (150000.0, 'pt', 3000)
# (150000.0, 'lesabre', 3500)
# (150000.0, 'century', 2850)
# (150000.0, 'sportage', 7995)
# (150000.0, 'escape', 2700)
# (150000.0, 'f-150', 5500)
# (150000.0, 'f150', 4900)
# (150000.0, 'silverado', 8995)
# (150000.0, 'f-150', 2000)
# (150000.0, 'pt', 3000)
# (150000.0, 'lesabre', 3500)
# (150000.0, 'century', 2850)
# (150000.0, 'sportage', 7995)
# (150000.0, 'escape', 2700)
# (150000.0, 'altima', 5500)
# (150000.0, 'pt', 3800)
# (150000.0, 'fusion', 7000)
# (150000.0, 'mustang', 5500)
# (150000.0, 'pilot', 6250)
# (150000.0, 'armada', 11500)
# (150000.0, 'g35', 5000)
# (150000.0, 'f250', 8500)
# (150000.0, 'f-150', 5795)
# (150000.0, 'f-150', 5795)
# (150000.0, 'grand', 4500)
# (150000.0, 'f150', 14750)
# ...

# %%
sql = "SELECT model1, manufacturer,price FROM cars WHERE cylinders like 8 Limit 2000"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('sierra', 'gmc', 33590)
# ('silverado', 'chevrolet', 22590)
# ('silverado', 'chevrolet', 39590)
# ('tundra', 'toyota', 30990)
# ('sierra', 'gmc', 27990)
# ('corvette', 'chevrolet', 38590)
# ('camaro', 'chevrolet', 37990)
# ('1500', 'ram', 22590)
# ('f250', 'ford', 19900)
# ('sierra', 'gmc', 24590)
# ('1500', 'ram', 25990)
# ('mustang', 'ford', 34990)
# ('f450', 'ford', 22500)
# ('tundra', 'toyota', 31990)
# ('silverado', 'chevrolet', 29990)
# ('charger', 'dodge', 15000)
# ('1500', 'ram', 33990)
# ('sierra', 'gmc', 36590)
# ('sierra', 'gmc', 29590)
# ('f250', 'ford', 40590)
# ('f150', 'ford', 18950)
# ('f150', 'ford', 22950)
# ('gx470', 'lexus', 13950)
# ('silverado', 'chevrolet', 39590)
# ('titan', 'nissan', 26990)
# ('f150', 'ford', 5900)
# ('silverado', 'chevrolet', 32000)
# ('sierra', 'gmc', 33590)
# ('yukon', 'gmc', 12500)
# ('sierra', 'gmc', 27990)
# ('tahoe', 'chevrolet', 3500)
# ('corvette', 'chevrolet', 35590)
# ('silverado', 'chevrolet', 45000)
# ...

# %%
sql = "SELECT count(manufacturer),sum(price)  FROM cars WHERE manufacturer LIKE 'ford' "

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (39182, Decimal('709393946'))

# %%
sql = "SELECT manufacturer,model1, price FROM cars ORDER BY price desc LIMIT 100"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('chevrolet', 'silverado', 54950)
# ('chevrolet', 'silverado', 54950)
# ('ram', '5500', 54950)
# ('gmc', 'sierra', 54950)
# ('gmc', 'sierra', 54950)
# ('chevrolet', 'silverado', 54950)
# ('chevrolet', 'silverado', 54950)
# ('ram', '5500', 54950)
# ('ford', 'f-150', 54900)
# ('ram', '3500', 54900)
# ('gmc', 'sierra', 54900)
# ('ram', '3500', 54900)
# ('jeep', 'wrangler', 54900)
# ('ford', 'f-150', 54900)
# ('jeep', 'wrangler', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f550', 54900)
# ('jeep', 'grand', 54900)
# ('jeep', 'grand', 54900)
# ('ford', 'f550', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f550', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f550', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f550', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f250', 54900)
# ('jeep', 'grand', 54900)
# ('ram', '2500', 54900)
# ('ford', 'f-250', 54900)
# ('ram', '3500', 54900)
# ('gmc', 'sierra', 54900)
# ('ram', '3500', 54900)
# ('ford', 'f-150', 54900)
# ('jeep', 'wrangler', 54900)
# ...

# %%
sql = "SELECT avg(price),avg(odometer)  FROM cars where model1 like 'f150' "

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (Decimal('25494.5642'), 75854.12220039293)

# %%
sql = "SELECT avg(price),avg(odometer)  FROM cars where (model1 like 'f150') and (year BETWEEN 2010 AND 2013) "

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (Decimal('19251.5363'), 101983.8778761062)

# %%
sql = "SELECT odometer,price,manufacturer,model1 FROM cars WHERE ((price > 15000) AND (price < 20000)) AND ((odometer > 100000) AND (odometer <150000)) AND (model1 like 'silverado') ORDER BY price ASC "

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (132000.0, 15200, 'chevrolet', 'silverado')
# (132000.0, 15200, 'chevrolet', 'silverado')
# (129500.0, 15300, 'chevrolet', 'silverado')
# (129500.0, 15300, 'chevrolet', 'silverado')
# (137647.0, 15495, 'chevrolet', 'silverado')
# (112467.0, 15495, 'chevrolet', 'silverado')
# (137647.0, 15495, 'chevrolet', 'silverado')
# (112467.0, 15495, 'chevrolet', 'silverado')
# (120000.0, 15500, 'chevrolet', 'silverado')
# (120000.0, 15500, 'chevrolet', 'silverado')
# (109324.0, 15500, 'chevrolet', 'silverado')
# (119998.0, 15500, 'chevrolet', 'silverado')
# (133976.0, 15500, 'chevrolet', 'silverado')
# (134000.0, 15500, 'chevrolet', 'silverado')
# (140000.0, 15500, 'chevrolet', 'silverado')
# (133976.0, 15500, 'chevrolet', 'silverado')
# (129000.0, 15500, 'chevrolet', 'silverado')
# (120000.0, 15500, 'chevrolet', 'silverado')
# (120000.0, 15500, 'chevrolet', 'silverado')
# (120916.0, 15500, 'chevrolet', 'silverado')
# (120000.0, 15500, 'chevrolet', 'silverado')
# ...
